# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj-chhabra/collab/blob/master/matplot/matplot-line-chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3
years = [1950,1960, 1970,1980, 1990,2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5976.6, 10289.7, 14958.3]

# Create a Line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

plt.title('Nominal GDP')

#add a lable to y axis
plt.ylabel("Billions of $")
plt.show()
